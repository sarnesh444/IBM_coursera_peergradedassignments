# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# # Saranesh ManiRatna.K
# Aspiring DataScientist

# %% [markdown]
# *I am interested in data science because of the plethora of opportunites it has to offer,also the computational thinking makes feel that I can fit the bill,moreover the field is evolving exponetially on a daily basis making the learning curve steep,I was always intrigued by the things I dont know,this keeps the fire in me alive*

# %% [markdown]
# ### My code can be used to unpack a list and print it!

# %%
lis=[1,2,3]
print(lis) #print before unpacking a list
print(*lis) #print after unpacking a list
# Out:
# [1, 2, 3]
# 1 2 3

# %% [markdown]
# # numbered list
# 1. one
# 1. two
# 1. three

# %% [markdown]
# ~~Strike through~~

# %% [markdown]
# <a href="https://www.youtube.com/">Youtube</a>

# %% [markdown]
# > Blockquotes are very handy in email to emulate reply text.
